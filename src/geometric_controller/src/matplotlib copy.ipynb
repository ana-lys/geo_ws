# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ptick
from matplotlib.pyplot import figure
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl

# %%
data_blue = pd.read_csv("/home/analys/log csv/vel_drag.csv")

# %%
data_blue.head()
# Out:
#       AX_FB  Vel_X_des
# 0  0.310739      0.000
# 1  0.650826      0.495
# 2 -0.118718     -0.735
# 3  0.986922      0.981
# 4 -0.459570     -1.225

# %%
# plt.figure(figsize=(10,7))   # Set the size of your plot. It will determine the relative size of all the labels.
# plt.figure(dpi=600)
# plt.plot(data_blue['TimeStamp'],data_blue['setAX'],label="Desired AX",linewidth =0.3)
# plt.plot(data_blue['TimeStamp'],data_blue['ImuX'],label="ImuAX",linewidth =0.3)
plt.grid()
plt.plot(data_blue['AX_FB'],data_blue['Vel_X_des'],marker="o",markersize=2)

# plt.plot(data_blue['TimeStamp'],data_blue['feedbackX'],label="feed back AX",linewidth =0.3)
 # Plot a curve.
plt.xlabel("Time")
plt.ylabel("AX")
plt.title("Constant velocity testing limited space(drag model not applied")
plt.legend()
plt.savefig('/home/analys/log csv/velo_pos_a1.png', dpi=600)
plt.show()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# No handles with labels found to put in legend.
